# %% [markdown]
# Python Review:
# Importing an Excel/CSV File
# Importing a text file
# Print the Header or First line of a file or table
# Row count
# Find Missing Values
# Line Break when printing
# Convert to Date/ Time Datatype
# Connecting  to another database server using DBeaver
# Pivot Table
# Find Duplicates
# Remove Duplicates
# Add Row ID
# Close connection to SQL
# Table and Field Name Description/Data type
# Line Break in Code
# Delete a row
# Format Dates
# Find Date Gaps or missing dates
# Create Calendar with Date Range
# Query a database
# Merge or Join data
# Read files in a directory
# Summarize data
# Group by
# Sort Data
# Create Subset of data
# Count by year
# "Delete null values, create new dataset
# (never remove nulls from original dataset)"
# Date Range or value range in a column
# Create new column with ranges based on column values
# Find unique values in a single column/variable
# Count null values in each column
# Renaming columns
# Graph: Bubble plots
# Change datatype

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import sqlite3
import json
from pandasql import sqldf
pd.set_option('display.max_rows',None)

# %%
cw = pd.read_csv('CountriesWorld.csv') #import certain rows
cw.head()
cw.tail()
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
# ...

# %%
#Print the Header or First line of a file or table
cw.head(0)
# Out:
# Empty DataFrame
# Columns: [Country, Region, Population, Area (sq. mi.), Pop. Density (per sq. mi.), Coastline (coast/area ratio), Net migration, Infant mortality (per 1000 births), GDP ($ per capita), Literacy, Phones (per 1000), Arable, Crops, Other, Climate, Birthrate, Deathrate, Agriculture, Industry, Service]
# Index: []

# %%
cw.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy', 'Phones (per 1000)', 'Arable',
#        'Crops', 'Other', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
#        'Industry', 'Service'],
#       dtype='object')

# %%
#create list from dataframe
cw_col = list(cw.columns)
cw_col
# Out:
# ['Country',
#  'Region',
#  'Population',
#  'Area (sq. mi.)',
#  'Pop. Density (per sq. mi.)',
#  'Coastline (coast/area ratio)',
#  'Net migration',
#  'Infant mortality (per 1000 births)',
#  'GDP ($ per capita)',
#  'Literacy',
#  'Phones (per 1000)',
#  'Arable',
#  'Crops',
#  'Other',
#  'Climate',
#  'Birthrate',
#  'Deathrate',
#  'Agriculture',
#  'Industry',
#  'Service']

# %%
#Row count
len(cw)
# Out:
# 227

# %%
#Row columns
len(cw.columns)
# Out:
# 20

# %%
#Find Missing Values
cw.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy                              18
# Phones (per 1000)                      4
# Arable                                 2
# Crops                                  2
# Other                                  2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
#return the first 2 values using an index
cw.iloc[0,1]
# Out:
# 'ASIA (EX. NEAR EAST)         '

# %%
#return the first 2 columns using an index
cw.iloc[0:1]
# Out:
#         Country                         Region  Population  Area (sq. mi.)  \
# 0  Afghanistan   ASIA (EX. NEAR EAST)             31056997          647500
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                        48.0                           0.0          23.06
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy  \
# 0                              163.07               700.0      36.0
#
#    Phones (per 1000)  Arable  Crops  Other  Climate  Birthrate  Deathrate  \
# 0                3.2   12.13   0.22  87.65      1.0       46.6      20.34
#
#    Agriculture  Industry  Service
# 0         0.38      0.24     0.38

# %%
#return the first 2 columns
cw2 = cw[['Country','Region']].head(10)
cw2
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %%
#data frame to a dictionary key-value pairs
cw2_dict =  cw2.to_dict()
cw2_dict
# Out:
# {'Country': {0: 'Afghanistan ',
#   1: 'Albania ',
#   2: 'Algeria ',
#   3: 'American Samoa ',
#   4: 'Andorra ',
#   5: 'Angola ',
#   6: 'Anguilla ',
#   7: 'Antigua & Barbuda ',
#   8: 'Argentina ',
#   9: 'Armenia '},
#  'Region': {0: 'ASIA (EX. NEAR EAST)         ',
#   1: 'EASTERN EUROPE                     ',
#   2: 'NORTHERN AFRICA                    ',
#   3: 'OCEANIA                            ',
#   4: 'WESTERN EUROPE                     ',
#   5: 'SUB-SAHARAN AFRICA                 ',
#   6: 'LATIN AMER. & CARIB    ',
#   7: 'LATIN AMER. & CARIB    ',
#   8: 'LATIN AMER. & CARIB    ',
#   9: 'C.W. OF IND. STATES '}}

# %%
#Add an id column starting with 1
cw2 = cw2.reset_index()
cw2
# Out:
#    index             Country                               Region
# 0      0        Afghanistan         ASIA (EX. NEAR EAST)
# 1      1            Albania   EASTERN EUROPE
# 2      2            Algeria   NORTHERN AFRICA
# 3      3     American Samoa   OCEANIA
# 4      4            Andorra   WESTERN EUROPE
# 5      5             Angola   SUB-SAHARAN AFRICA
# 6      6           Anguilla               LATIN AMER. & CARIB
# 7      7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8      8          Argentina               LATIN AMER. & CARIB
# 9      9            Armenia                  C.W. OF IND. STATES

# %%
col_id = 11

for index in col_id:
    col_id+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 col_id = 11
# ----> 3 for index in col_id:
#       4     col_id+=1
#
# TypeError: 'int' object is not iterable

# %%
#def add_col(x):

# %%
#lambda func or anomymous func by adding an id column with numbers from 1-10
cw2['id']=cw2.apply(lambda row: row.name+1, axis=1)
cw2
# Out:
#    index             Country                               Region  id
# 0      0        Afghanistan         ASIA (EX. NEAR EAST)            1
# 1      1            Albania   EASTERN EUROPE                        2
# 2      2            Algeria   NORTHERN AFRICA                       3
# 3      3     American Samoa   OCEANIA                               4
# 4      4            Andorra   WESTERN EUROPE                        5
# 5      5             Angola   SUB-SAHARAN AFRICA                    6
# 6      6           Anguilla               LATIN AMER. & CARIB       7
# 7      7  Antigua & Barbuda               LATIN AMER. & CARIB       8
# 8      8          Argentina               LATIN AMER. & CARIB       9
# 9      9            Armenia                  C.W. OF IND. STATES   10

# %%
cw2['id2_map']=cw2.index.map(lambda x: x+1)
cw2
# Out:
#    index             Country                               Region  id  id2_map
# 0      0        Afghanistan         ASIA (EX. NEAR EAST)            1        1
# 1      1            Albania   EASTERN EUROPE                        2        2
# 2      2            Algeria   NORTHERN AFRICA                       3        3
# 3      3     American Samoa   OCEANIA                               4        4
# 4      4            Andorra   WESTERN EUROPE                        5        5
# 5      5             Angola   SUB-SAHARAN AFRICA                    6        6
# 6      6           Anguilla               LATIN AMER. & CARIB       7        7
# 7      7  Antigua & Barbuda               LATIN AMER. & CARIB       8        8
# 8      8          Argentina               LATIN AMER. & CARIB       9        9
# 9      9            Armenia                  C.W. OF IND. STATES   10       10

# %%
#write a for loop to go through the country column
for x in cw2['Country']:
    print(x)
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antigua & Barbuda
# Argentina
# Armenia

# %%
#filter for the even ids
cw2_even = cw2.query('id%2==0')
cw2_even
# Out:
#    index             Country                               Region  id  id2_map
# 1      1            Albania   EASTERN EUROPE                        2        2
# 3      3     American Samoa   OCEANIA                               4        4
# 5      5             Angola   SUB-SAHARAN AFRICA                    6        6
# 7      7  Antigua & Barbuda               LATIN AMER. & CARIB       8        8
# 9      9            Armenia                  C.W. OF IND. STATES   10       10

# %%
counter = 0
for x in cw2['Country']:
    counter = counter + 1
    if ((counter%2) == 0):
        print(x)
# Out:
# Albania
# American Samoa
# Angola
# Antigua & Barbuda
# Armenia

# %%
#Add a column called 'odd_even' with values 'even' or 'odd' based on the column 'id'
cw2['even_odd_tay'] = cw2.id % 2
odd_even = []
counter = 0
for x in cw2['Country']:
    counter = counter + 1
    if ((counter%2) == 0):
        odd_even.append('Even')
    else:
         odd_even.append('odd')
cw2['odd_even'] = odd_even
#cw2
cw2.insert(5,'odd_even2',odd_even)
cw2
# Out:
#    index             Country                               Region  id  \
# 0      0        Afghanistan         ASIA (EX. NEAR EAST)            1
# 1      1            Albania   EASTERN EUROPE                        2
# 2      2            Algeria   NORTHERN AFRICA                       3
# 3      3     American Samoa   OCEANIA                               4
# 4      4            Andorra   WESTERN EUROPE                        5
# 5      5             Angola   SUB-SAHARAN AFRICA                    6
# 6      6           Anguilla               LATIN AMER. & CARIB       7
# 7      7  Antigua & Barbuda               LATIN AMER. & CARIB       8
# 8      8          Argentina               LATIN AMER. & CARIB       9
# 9      9            Armenia                  C.W. OF IND. STATES   10
#
#    id2_map odd_even2 odd_even  even_odd_tay
# 0        1       odd      odd             1
# 1        2      Even     Even             0
# 2        3       odd      odd             1
# ...

# %%
#drop column
cw2=cw2.drop(columns = 'even_odd_tay', axis = 1)
cw2=cw2.drop(columns = 'odd_even2', axis = 1)
cw2
# Out:
#    index             Country                               Region  id  \
# 0      0        Afghanistan         ASIA (EX. NEAR EAST)            1
# 1      1            Albania   EASTERN EUROPE                        2
# 2      2            Algeria   NORTHERN AFRICA                       3
# 3      3     American Samoa   OCEANIA                               4
# 4      4            Andorra   WESTERN EUROPE                        5
# 5      5             Angola   SUB-SAHARAN AFRICA                    6
# 6      6           Anguilla               LATIN AMER. & CARIB       7
# 7      7  Antigua & Barbuda               LATIN AMER. & CARIB       8
# 8      8          Argentina               LATIN AMER. & CARIB       9
# 9      9            Armenia                  C.W. OF IND. STATES   10
#
#    id2_map odd_even
# 0        1      odd
# 1        2     Even
# 2        3      odd
# 3        4     Even
# 4        5      odd
# 5        6     Even
# 6        7      odd
# 7        8     Even
# ...

# %%
cw2['odd_even'] = cw2['odd_even'].str.capitalize()
cw2
# Out:
#    index             Country                               Region  id  \
# 0      0        Afghanistan         ASIA (EX. NEAR EAST)            1
# 1      1            Albania   EASTERN EUROPE                        2
# 2      2            Algeria   NORTHERN AFRICA                       3
# 3      3     American Samoa   OCEANIA                               4
# 4      4            Andorra   WESTERN EUROPE                        5
# 5      5             Angola   SUB-SAHARAN AFRICA                    6
# 6      6           Anguilla               LATIN AMER. & CARIB       7
# 7      7  Antigua & Barbuda               LATIN AMER. & CARIB       8
# 8      8          Argentina               LATIN AMER. & CARIB       9
# 9      9            Armenia                  C.W. OF IND. STATES   10
#
#    id2_map odd_even
# 0        1      Odd
# 1        2     Even
# 2        3      Odd
# 3        4     Even
# 4        5      Odd
# 5        6     Even
# 6        7      Odd
# 7        8     Even
# ...
