# %%
import pandas as pd

# %%
df = pd.read_csv('SampleDatabase_AlbumTotalSales.csv')
df
# Out:
#                                             Artist_Name  \
# 0                                                 AC/DC
# 1                                                 AC/DC
# 2             Aaron Copland & London Symphony Orchestra
# 3                                        Aaron Goldberg
# 4     Academy of St. Martin in the Fields & Sir Nevi...
# ...                                                 ...
# 1102                                     Zeca Pagodinho
# 1103                                     Zeca Pagodinho
# 1104                                     Zeca Pagodinho
# 1105                                     Zeca Pagodinho
# 1106                                     Zeca Pagodinho
#
#                                 Album_Title      Genre  \
# 0     For Those About To Rock We Salute You       Rock
# 1                         Let There Be Rock       Rock
# 2             A Copland Celebration, Vol. I  Classical
# 3                                    Worlds       Jazz
# ...

# %%
# creating a data frame from a dictionary
myvar = pd.DataFrame(df)
myvar
# Out:
#                                             Artist_Name  \
# 0                                                 AC/DC
# 1                                                 AC/DC
# 2             Aaron Copland & London Symphony Orchestra
# 3                                        Aaron Goldberg
# 4     Academy of St. Martin in the Fields & Sir Nevi...
# ...                                                 ...
# 1102                                     Zeca Pagodinho
# 1103                                     Zeca Pagodinho
# 1104                                     Zeca Pagodinho
# 1105                                     Zeca Pagodinho
# 1106                                     Zeca Pagodinho
#
#                                 Album_Title      Genre  \
# 0     For Those About To Rock We Salute You       Rock
# 1                         Let There Be Rock       Rock
# 2             A Copland Celebration, Vol. I  Classical
# 3                                    Worlds       Jazz
# ...

# %%
myvar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Artist_Name          1107 non-null   object
#  1   Album_Title          1107 non-null   object
#  2   Genre                1107 non-null   object
#  3   Composer             1017 non-null   object
#  4   Total_Album_Sales    1107 non-null   float64
#  5   Total_Quantity_Sold  765 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 52.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Artist_Name          1107 non-null   object
#  1   Album_Title          1107 non-null   object
#  2   Genre                1107 non-null   object
#  3   Composer             1017 non-null   object
#  4   Total_Album_Sales    1107 non-null   float64
#  5   Total_Quantity_Sold  765 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 52.0+ KB

# %%
#Data Quality
print(df.head(10)) #top rows
print(df.tail(10)) #bottom rows
# Out:
#                                          Artist_Name  \
# 0                                              AC/DC
# 1                                              AC/DC
# 2          Aaron Copland & London Symphony Orchestra
# 3                                     Aaron Goldberg
# 4  Academy of St. Martin in the Fields & Sir Nevi...
# 5  Academy of St. Martin in the Fields & Sir Nevi...
# 6  Academy of St. Martin in the Fields Chamber En...
# 7  Academy of St. Martin in the Fields, John Birc...
# 8  Academy of St. Martin in the Fields, Sir Nevil...
# 9                                             Accept
#
#                               Album_Title      Genre  \
# 0   For Those About To Rock We Salute You       Rock
# 1                       Let There Be Rock       Rock
# 2           A Copland Celebration, Vol. I  Classical
# 3                                  Worlds       Jazz
# 4       The World of Classical Favourites  Classical
# 5       The World of Classical Favourites  Classical
# ...

# %%
df.head(10) #top rows
# Out:
#                                          Artist_Name  \
# 0                                              AC/DC
# 1                                              AC/DC
# 2          Aaron Copland & London Symphony Orchestra
# 3                                     Aaron Goldberg
# 4  Academy of St. Martin in the Fields & Sir Nevi...
# 5  Academy of St. Martin in the Fields & Sir Nevi...
# 6  Academy of St. Martin in the Fields Chamber En...
# 7  Academy of St. Martin in the Fields, John Birc...
# 8  Academy of St. Martin in the Fields, Sir Nevil...
# 9                                             Accept
#
#                               Album_Title      Genre  \
# 0   For Those About To Rock We Salute You       Rock
# 1                       Let There Be Rock       Rock
# 2           A Copland Celebration, Vol. I  Classical
# 3                                  Worlds       Jazz
# 4       The World of Classical Favourites  Classical
# 5       The World of Classical Favourites  Classical
# ...

# %%
df.tail(10)  #bottom rows
# Out:
#          Artist_Name       Album_Title  Genre  \
# 1097  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
# 1098  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
# 1099  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
# 1100  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
# 1101  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
# 1102  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
# 1103  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
# 1104  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
# 1105  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
# 1106  Zeca Pagodinho  Ao Vivo [IMPORT]  Latin
#
#                              Composer  Total_Album_Sales  Total_Quantity_Sold
# 1097  Carlinhos Santana/Nelson Rufino               0.99                  1.0
# 1098                       Dudu Nobre               0.99                  NaN
# 1099        Dudu Nobre/Zeca Pagodinho               0.99                  NaN
# 1100         Grazielle/Roque Ferreira               0.99                  1.0
# ...

# %%
#checking Data types
df.dtypes
# Out:
# Artist_Name             object
# Album_Title             object
# Genre                   object
# Composer                object
# Total_Album_Sales      float64
# Total_Quantity_Sold    float64
# dtype: object

# %%
#list of columns
df.columns
# Out:
# Index(['Artist_Name', 'Album_Title', 'Genre', 'Composer', 'Total_Album_Sales',
#        'Total_Quantity_Sold'],
#       dtype='object')

# %%
#Count of Columns
len(df.columns)
# Out:
# 6

# %%
#Count of Rows
len(df)
# Out:
# 1107

# %%
#Total number of missing values
df.isnull().sum()
# Out:
# Artist_Name              0
# Album_Title              0
# Genre                    0
# Composer                90
# Total_Album_Sales        0
# Total_Quantity_Sold    342
# dtype: int64

# %%
#Unique values
df['Album_Title'].nunique()
# Out:
# 347

# %%
df['Album_Title']
# Out:
# 0       For Those About To Rock We Salute You
# 1                           Let There Be Rock
# 2               A Copland Celebration, Vol. I
# 3                                      Worlds
# 4           The World of Classical Favourites
#                         ...
# 1102                         Ao Vivo [IMPORT]
# 1103                         Ao Vivo [IMPORT]
# 1104                         Ao Vivo [IMPORT]
# 1105                         Ao Vivo [IMPORT]
# 1106                         Ao Vivo [IMPORT]
# Name: Album_Title, Length: 1107, dtype: object

# %%
df_new = pd.DataFrame(df[['Artist_Name', 'Total_Album_Sales', 'Total_Quantity_Sold']])
df_new
# Out:
#                                             Artist_Name  Total_Album_Sales  \
# 0                                                 AC/DC              11.88
# 1                                                 AC/DC               8.91
# 2             Aaron Copland & London Symphony Orchestra               0.99
# 3                                        Aaron Goldberg               0.99
# 4     Academy of St. Martin in the Fields & Sir Nevi...               0.99
# ...                                                 ...                ...
# 1102                                     Zeca Pagodinho               0.99
# 1103                                     Zeca Pagodinho               0.99
# 1104                                     Zeca Pagodinho               0.99
# 1105                                     Zeca Pagodinho               0.99
# 1106                                     Zeca Pagodinho               0.99
#
#       Total_Quantity_Sold
# 0                    10.0
# ...

# %%
# Using your Music Analysis data, create a subset of the data with variable name called ”artists_sales” with columns Artists, Genre, and Total Sales.  Remove the null values in the data. 

# How many rows and columns are in the new data set?
artists_sales = pd.DataFrame(df[['Artist_Name', 'Genre', 'Total_Album_Sales']])
artists_sale = artists_sales.fillna(0)
print('rows: ', len(artists_sale.index))
print('columns: ', len(artists_sale.columns))
artists_sale
# Out:
# rows:  1107
# columns:  3
#                                             Artist_Name      Genre  \
# 0                                                 AC/DC       Rock
# 1                                                 AC/DC       Rock
# 2             Aaron Copland & London Symphony Orchestra  Classical
# 3                                        Aaron Goldberg       Jazz
# 4     Academy of St. Martin in the Fields & Sir Nevi...  Classical
# ...                                                 ...        ...
# 1102                                     Zeca Pagodinho      Latin
# 1103                                     Zeca Pagodinho      Latin
# 1104                                     Zeca Pagodinho      Latin
# 1105                                     Zeca Pagodinho      Latin
# 1106                                     Zeca Pagodinho      Latin
#
#       Total_Album_Sales
# 0                 11.88
# 1                  8.91
# 2                  0.99
# 3                  0.99
# ...

# %%
artists_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Artist_Name        1107 non-null   object
#  1   Genre              1107 non-null   object
#  2   Total_Album_Sales  1107 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 26.1+ KB

# %%
#count Null
df.isna().count()
# Out:
# Artist_Name            1107
# Album_Title            1107
# Genre                  1107
# Composer               1107
# Total_Album_Sales      1107
# Total_Quantity_Sold    1107
# dtype: int64

# %%
#Aggregate Functions
artists_sale.describe()
# Out:
#        Total_Album_Sales
# count        1107.000000
# mean            3.561346
# std             5.557004
# min             0.990000
# 25%             0.990000
# 50%             0.990000
# 75%             2.970000
# max            51.740000
