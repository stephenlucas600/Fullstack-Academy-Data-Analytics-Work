# %%
#import libaries
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import sqlite3
import json

pd.set_option('display.max_rows', None)

# %%
a=1
lambda a: a+a
# Out:
# <function __main__.<lambda>(a)>

# %%
x=lambda b,c: c*b
x(5,6)
# Out:
# 30

# %%
df=pd.read_excel('mlb_batting.xlsx')
df.head(10)
# Out:
#    Unnamed: 0   playerID  yearID  stint teamID lgID    G   AB    R    H  2B  \
# 0           0  abbotje01    2000      1    CHA   AL   80  215   31   59  15
# 1           1  abbotku01    2000      1    NYN   NL   79  157   22   34   7
# 2           2  abbotpa01    2000      1    SEA   AL   35    5    1    2   1
# 3           3  abreubo01    2000      1    PHI   NL  154  576  103  182  42
# 4           4  aceveju01    2000      1    MIL   NL   62    1    1    0   0
# 5           5  adamste01    2000      1    LAN   NL   66    2    0    0   0
# 6           6  agbaybe01    2000      1    NYN   NL  119  350   59  101  19
# 7           7  aguilri01    2000      1    CHN   NL   54    0    0    0   0
# 8           8  alcanis01    2000      1    BOS   AL   21   45    9   13   1
# 9           9  aldresc01    2000      1    PHI   NL   23    0    0    0   0
#
#    3B  HR  RBI  SB  CS   BB   SO
# 0   1   3   29   2   1   21   38
# 1   1   6   12   1   1   14   51
# ...

# %%
df_r =df[['teamID', 'R']]
print(df_r)
df_r['R'] = df_r.groupby('teamID').filter(lambda x: x['R'].sum() > 100)
# Out:
#       teamID    R
# 0        CHA   31
# 1        NYN   22
# 2        SEA    1
# 3        PHI  103
# 4        MIL    1
# 5        LAN    0
# 6        NYN   59
# 7        CHN    0
# 8        BOS    9
# 9        PHI    0
# 10       BOS   30
# 11       FLO    0
# 12       NYN  109
# 13       TEX   85
# 14       MIN    2
# 15       SDN    0
# 16       DET    5
# 17       FLO    0
# 18       SDN    0
# 19       CLE  111
# 20       CLE   44
# 21       HOU   82
# 22       PHI    1
# 23       DET    0
# 24       SDN    1
# 25       ANA    0
# 26       BAL   10
# 27       BAL   89
# 28       ARI    4
# 29       ANA   92
# 30       PIT    5
# 31       DET    0
# 32       PHI   10
# 33       TOR    0
# 34       CHN   25
# 35       SLN    8
# 36       OAK    0
# 37       MIN    4
# 38       PHI   17
# 39       MON    1
# 40       LAN    0
# 41       CHN    0
# 42       COL    2
# 43       BOS    0
# 44       PIT    2
# 45       PHI    0
# 46       ATL    2
# 47       COL    2
# 48       SFN   67
# ...

# %%
x=lambda b: b+25
print(x(5))
# Out:
# 30

# %%
class MyClass:
    x=5
    
print(MyClass().x)
MyClass().x
# Out:
# 5
# 5

# %%
b1 = MyClass()
b1.x
# Out:
# 5

# %%
class Customer:
    def __init__(contact, name, age):
        contact.name = name
        contact.age = age
p1 = Customer('Sam',26)

# %%
print(p1.name)
print(p1.age)
# Out:
# Sam
# 26

# %%
#Scope
#local Scope

def newfunc():
    x=200
    print(x)

newfunc()
# Out:
# 200

# %%
#Global Scope
x= 300

def myfunc():
    print(x)
    newfunc()
myfunc()
# Out:
# 300
# 200

# %%
#modules
def greeting(name):
    print('Hello',+ name)

# %%
import greeting_module

# %%
greeting_module.greeting('stephen')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 greeting_module.greeting('stephen')
#
# AttributeError: module 'greeting_module' has no attribute 'greeting'
